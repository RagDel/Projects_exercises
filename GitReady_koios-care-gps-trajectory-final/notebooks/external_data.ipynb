# %%
import pandas as pd
import pickle
from tqdm import tqdm
import requests

# %%
qol_df = pd.read_csv('../data/external/QoL Numbeo.txt', sep='\t', header=None)

with open('../data/external/QoL Numbeo column names.txt', 'r', encoding='UTF-8') as file:
    qol_column_names = file.read().splitlines()

qol_df.columns = qol_column_names
qol_df.set_index('Rank', inplace=True)

# %%
qol_df.head(6)
# Out:
#                                    City  Quality of Life Index  \
# Rank
# 1     The Hague (Den Haag), Netherlands                  215.7
# 2                Rotterdam, Netherlands                  202.5
# 3                Luxembourg, Luxembourg                  200.5
# 4                       Vienna, Austria                  197.7
# 5                       Valencia, Spain                  196.3
# 6                Amsterdam, Netherlands                  194.8
#
#       Purchasing Power Index  Safety Index  Health Care Index  \
# Rank
# 1                      123.7          79.3               79.9
# 2                      115.0          71.1               79.7
# 3                      124.2          72.0               79.0
# 4                      104.0          72.6               78.9
# 5                       94.4          70.1               79.8
# 6                      108.2          70.9               77.3
#
#       Cost of Living Index  Property Price to Income Ratio  \
# Rank
# ...

# %%
# qol_df['City'] = qol_df['City'].str.replace(',', ' -')

# def parse_city_name(full_city_name):
#     # Splitting by '-' and taking the first part (city name)
#     return full_city_name.split('-')[0].strip()

# API_KEY = 'AIzaSyDCL0QT2X4-JMar3AxMbDaFrHrDChTTmeo'

# def geocode_city(city_name, api_key):
#     geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={city_name}&key={api_key}"
#     print(city_name)
#     response = requests.get(geocode_url)
#     response = response.json()
#     print(city_name)
#     if response['status'] == 'OK':
#         location = response['results'][0]['geometry']['location']
#         return location['lat'], location['lng']
#     else:
#         print(city_name)
#         return None, None


# # Assuming qol_df is your DataFrame and it has a column 'City'
# qol_df['Parsed City'] = qol_df['City'].apply(parse_city_name)

# # Geocode each city and create new columns for latitude and longitude
# latitudes = []
# longitudes = []
# for city in tqdm(qol_df['Parsed City']):
#     lat, lon = geocode_city(city, API_KEY)
#     latitudes.append(lat)
#     longitudes.append(lon)

# qol_df['City Center Latitude'] = latitudes
# qol_df['City Center Longitude'] = longitudes

# # Now qol_df has two new columns: 'City Center Latitude' and 'City Center Longitude'

# %%
#qol_df.to_pickle("../data/processed/qol_df.pkl")
